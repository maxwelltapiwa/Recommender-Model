# %% [markdown]
# Maxwell T Gwatidzo
# Recommender System

# %%
import pandas as pd

# %%
#data loading
data = pd.read_csv('jet shopping data 1.csv')

# %%
data
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)  Unnamed: 6 Size      Color  Season  \
# 0                        53         NaN    L       Gray  Winter
# 1                        64         NaN    L     Maroon  Winter
# ...

# %%
df=data

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#    Unnamed: 6 Size      Color  Season  Review Rating Subscription Status  \
# 0         NaN    L       Gray  Winter            3.1                 Yes
# 1         NaN    L     Maroon  Winter            3.1                 Yes
# 2         NaN    S     Maroon  Spring            3.1                 Yes
# 3         NaN    M     Maroon  Spring            3.5                 Yes
# 4         NaN    M  Turquoise  Spring            2.7                 Yes
#
#   Payment Method  Unnamed: 13 Discount Applied Promo Code Used  \
# ...

# %%
data.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)  Unnamed: 6 Size      Color  Season  \
# 3895                     28         NaN    L  Turquoise  Summer
# 3896                     49         NaN    L      White  Spring
# 3897                     33         NaN    L      Green  Spring
# 3898                     77         NaN    S      Brown  Summer
# 3899                     81         NaN    M      Beige  Spring
#
#       Review Rating Subscription Status Payment Method  Unnamed: 13  \
# 3895            4.2                  No           Cash          NaN
# 3896            4.5                  No         laybye          NaN
# ...

# %%
data.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Unnamed: 6', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method', 'Unnamed: 13',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Preferred Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Gender Distribution
gender_counts = data['Gender'].value_counts()
plt.figure(figsize=(15, 10))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %%
# Category Distribution
category_counts = data['Category'].value_counts()
plt.figure(figsize=(15, 10))
plt.bar(category_counts.index, category_counts.values)
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Category Distribution')
plt.xticks(rotation=45)
plt.show()

# %%
# Season Distribution
season_counts = data['Season'].value_counts()
plt.figure(figsize=(15, 8))
plt.bar(season_counts.index, season_counts.values)
plt.xlabel('Season')
plt.ylabel('Count')
plt.title('Season Distribution')
plt.show()

# %%
# Age Distribution
plt.figure(figsize=(15, 8))
plt.hist(data['Age'], bins=20)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %%
# Purchase Amount
plt.figure(figsize=(15, 8))
plt.boxplot(data['Purchase Amount (USD)'])
plt.ylabel('Purchase Amount (USD)')
plt.title('Purchase Amount Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt

# Age vs. Purchase Amount
plt.figure(figsize=(15, 8))
plt.scatter(data['Age'], data['Purchase Amount (USD)'])
plt.xlabel('Age')
plt.ylabel('Purchase Amount (USD)')
plt.title('Age vs. Purchase Amount')
plt.show()

# %%
# Previous Purchases vs. Frequency of Purchases
plt.figure(figsize=(15, 8))
plt.scatter(data['Previous Purchases'], data['Frequency of Purchases'])
plt.xlabel('Previous Purchases')
plt.ylabel('Frequency of Purchases')
plt.title('Previous Purchases vs. Frequency of Purchases')
plt.show()

# %%
# Payment Method
payment_counts = data['Payment Method'].value_counts()
plt.figure(figsize=(15, 8))
plt.bar(payment_counts.index, payment_counts.values)
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.title('Payment Method Distribution')
plt.xticks(rotation=45)
plt.show()

# %%
# Discount Applied
discount_counts = data['Discount Applied'].value_counts()
plt.figure(figsize=(15, 8))
plt.bar(discount_counts.index, discount_counts.values)
plt.xlabel('Discount Applied')
plt.ylabel('Count')
plt.title('Discount Applied Distribution')
plt.show()

# %%
import numpy as np
import seaborn as sns

# Average Review Rating by Category
category_rating_pivot = data.pivot_table(index='Category', columns='Review Rating', values='Customer ID', aggfunc='count', fill_value=0)
plt.figure(figsize=(15, 8))
sns.heatmap(category_rating_pivot, annot=True, cmap='Blues')
plt.xlabel('Review Rating')
plt.ylabel('Category')
plt.title('Average Review Rating by Category')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='Purchase Amount (USD)', data=data)
plt.xlabel('Category')
plt.ylabel('Purchase Amount (USD)')
plt.title('Box Plot by Category')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(15, 8))
sns.violinplot(x='Gender', y='Purchase Amount (USD)', data=data)
plt.xlabel('Gender')
plt.ylabel('Purchase Amount (USD)')
plt.title('Violin Plot by Gender')
plt.show()

# %%
season_avg_purchase = data.groupby('Season')['Purchase Amount (USD)'].mean()
plt.figure(figsize=(15, 8))
plt.bar(season_avg_purchase.index, season_avg_purchase.values)
plt.xlabel('Season')
plt.ylabel('Average Purchase Amount (USD)')
plt.title('Average Purchase Amount by Season')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.regplot(x='Age', y='Purchase Amount (USD)', data=data)
plt.xlabel('Age')
plt.ylabel('Purchase Amount (USD)')
plt.title('Scatter Plot with Regression Line')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(15, 8))
sns.histplot(data['Age'], kde=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Histogram with KDE')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.pairplot(data[['Age', 'Purchase Amount (USD)', 'Previous Purchases']])
plt.show()

# %%
top_n = 10
top_customers = data.groupby('Customer ID')['Purchase Amount (USD)'].sum().nlargest(top_n)

plt.figure(figsize=(15, 8))
plt.bar(top_customers.index, top_customers.values)
plt.xlabel('Customer ID')
plt.ylabel('Total Purchase Amount (USD)')
plt.title(f'Top {top_n} Customers by Purchase Amount')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.countplot(data['Review Rating'])
plt.xlabel('Review Rating')
plt.ylabel('Count')
plt.title('Distribution of Review Ratings')
plt.show()
# Out:
# c:\Users\llywellynn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Unnamed: 6', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method', 'Unnamed: 13',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Preferred Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
data = data.drop('Customer ID', axis=1)

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Item Purchased', 'Category', 'Purchase Amount (USD)',
#        'Unnamed: 6', 'Size', 'Color', 'Season', 'Review Rating',
#        'Subscription Status', 'Payment Method', 'Unnamed: 13',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Preferred Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
data.head()
# Out:
#    Age Gender Item Purchased  Category  Purchase Amount (USD)  Unnamed: 6  \
# 0   55   Male         Blouse  Clothing                     53         NaN
# 1   19   Male        Sweater  Clothing                     64         NaN
# 2   50   Male          Jeans  Clothing                     73         NaN
# 3   21   Male        Sandals  Footwear                     90         NaN
# 4   45   Male         Blouse  Clothing                     49         NaN
#
#   Size      Color  Season  Review Rating Subscription Status Payment Method  \
# 0    L       Gray  Winter            3.1                 Yes           cash
# 1    L     Maroon  Winter            3.1                 Yes  Bank Transfer
# 2    S     Maroon  Spring            3.1                 Yes           Cash
# 3    M     Maroon  Spring            3.5                 Yes           cash
# 4    M  Turquoise  Spring            2.7                 Yes           Cash
#
# ...

# %%
data.nunique()
# Out:
# Age                         53
# Gender                       2
# Item Purchased              25
# Category                     4
# Purchase Amount (USD)       81
# Unnamed: 6                   0
# Size                         4
# Color                       25
# Season                       4
# Review Rating               26
# Subscription Status          2
# Payment Method              10
# Unnamed: 13                  0
# Discount Applied             2
# Promo Code Used              2
# Previous Purchases          50
# Preferred Payment Method    11
# Frequency of Purchases       7
# dtype: int64

# %%
data = data.drop('Unnamed: 6', axis=1)

# %%
data = data.drop('Unnamed: 13', axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       3900 non-null   int64
#  1   Gender                    3900 non-null   object
#  2   Item Purchased            3900 non-null   object
#  3   Category                  3900 non-null   object
#  4   Purchase Amount (USD)     3900 non-null   int64
#  5   Size                      3900 non-null   object
#  6   Color                     3900 non-null   object
#  7   Season                    3900 non-null   object
#  8   Review Rating             3900 non-null   float64
#  9   Subscription Status       3900 non-null   object
#  10  Payment Method            3900 non-null   object
#  11  Discount Applied          3900 non-null   object
#  12  Promo Code Used           3900 non-null   object
# ...

# %%
data.head()
# Out:
#    Age Gender Item Purchased  Category  Purchase Amount (USD) Size      Color  \
# 0   55   Male         Blouse  Clothing                     53    L       Gray
# 1   19   Male        Sweater  Clothing                     64    L     Maroon
# 2   50   Male          Jeans  Clothing                     73    S     Maroon
# 3   21   Male        Sandals  Footwear                     90    M     Maroon
# 4   45   Male         Blouse  Clothing                     49    M  Turquoise
#
#    Season  Review Rating Subscription Status Payment Method Discount Applied  \
# 0  Winter            3.1                 Yes           cash              Yes
# 1  Winter            3.1                 Yes  Bank Transfer              Yes
# 2  Spring            3.1                 Yes           Cash              Yes
# 3  Spring            3.5                 Yes           cash              Yes
# 4  Spring            2.7                 Yes           Cash              Yes
#
# ...

# %%
# Select the numerical columns for creating QQ plots
import statsmodels.api as sm
numerical_columns = ['Age', 'Purchase Amount (USD)', 'Review Rating']

# Create QQ plots for each numerical column
for column in numerical_columns:
    sm.qqplot(data[column], line='s')
    plt.title(f'QQ Plot for {column}')
    plt.show()

# %% [markdown]
# # Building a Recommender System for item purchased in jet using Collaborative Filtering

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Unnamed: 6', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method', 'Unnamed: 13',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Preferred Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
features=['Customer ID','Item Purchased','Review Rating']

# %%
from surprise import Dataset
from surprise import Reader

# %%
pip install --use-pep517 surprise
# Out:
# ...
#   Using cached surprise-0.1-py2.py3-none-any.whl.metadata (327 bytes)
# ...
#   Using cached scikit-surprise-1.1.3.tar.gz (771 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [51 lines of output]
#       <string>:65: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
# ...

# %%
from surprise import Dataset
from surprise import Reader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-8857049f0d17> in <module>
# ----> 1 from surprise import Dataset
#       2 from surprise import Reader
#
# ModuleNotFoundError: No module named 'surprise'

# %% [markdown]
# ## determining rating scale

# %%
df['Review Rating'].max()
# Out:
# 5.0

# %%
df['Review Rating'].min()
# Out:
# 2.5

# %%
# choosing 2 as lowerbound and 5 as upperbound for rating(ie using integers for bounding)...
reader = Reader(rating_scale=(2, 5))

# %%
data = Dataset.load_from_df(df[features], reader)

# %% [markdown]
# ## Building model using item-based cosine similarity

# %%
from surprise import KNNWithMeans

# here is where item-based is specified
sim_options = {
    "name": "cosine",
    "user_based": False,  # Compute  similarities between items
}
algo = KNNWithMeans(sim_options=sim_options)

# %% [markdown]
# ## getting training set...

# %%
trainingSet = data.build_full_trainset()

# %%
algo.fit(trainingSet)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# ## testing model...

# %%
prediction1 = algo.predict(1,'Blouse')

# %%
prediction1.est
# Out:
# 3.1

# %%
def estimate(entry):
    prediction = algo.predict(*entry)
    return prediction.est

# %%
estimate((2,'Sweater'))
# Out:
# 3.1

# %%
estimate((4,'Sandals'))
# Out:
# 3.7192052980132453

# %% [markdown]
# # Results:
#
# ## out of the three tested, all products had correct predictions with:
#
# - 1,'Blouse' $\rightarrow$ 3.1 (correct)
# - 2,'Sweater' $\rightarrow$ 3.1 (correct) and
# - 4,'Sandals' $\rightarrow$ 3.1 (correct)
#
# futher testing the model will show that the predictions will not always be on point with the actual ratings but will still be close, eg 3.1 for an actual rating of 3.5
